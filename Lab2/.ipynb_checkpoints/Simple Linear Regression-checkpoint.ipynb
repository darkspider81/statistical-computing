# %% [markdown]
# # Simple linear regression - exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size.csv'.
#
# You are expected to create a simple linear regression (similar to the one in the lecture), using the new data.
#
# In this exercise, the dependent variable is 'price', while the independent variables is 'size'.
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd #import data that is stored locally
import matplotlib.pyplot as plt #used for ploting
import statsmodels.api as sm #all the models in statistics
from statsmodels.formula.api import ols

# %% [markdown]
# ## Load the data

# %%
data= pd.read_csv('real_estate_price_size.csv')

# %%
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %%
#dependent_variable 
y = data['price'] 
#independent_variable 
x1 = data['size']

# %% [markdown]
# ### Explore the data

# %%
plt.scatter(x1,y,c="blue",label='Data' )
plt.xlabel("Size", fontsize=18)
plt.ylabel("Price", fontsize=18)
plt.title('Regression Analysis', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# ### Regression itself

# %%
x=sm.add_constant(x1)
model=sm.OLS(y,x).fit()
results=model.summary()
results
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Fri, 30 Jun 2023   Prob (F-statistic):           8.13e-31
# Time:                        17:51:29   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# ...

# %% [markdown]
# ### Plot the regression line on the initial scatter

# %%
plt.scatter(x1,y,c="blue",label='Data' )
yhat=1.019e+05+223.1787*x1
plt.plot(x1,yhat,c="red",label='Regression Line')
plt.xlabel("Size", fontsize=18)
plt.ylabel("Price", fontsize=18)
plt.title('Regression Analysis', fontsize=20)
plt.legend()
plt.show()
